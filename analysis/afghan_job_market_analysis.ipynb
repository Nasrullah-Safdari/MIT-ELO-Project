# %% [markdown]
#  The data from ACBAR website is scraped between June-Sept 2023 in eight rounds.
# The data contain the following variables:
# 1. Location: different provinces in Afghanistan
# 2. Nationality: national, international, both
# 3. Job_Category: different job categories such as business, health care, IT, security,...
# 4. Employment Type: Full Time, Part Time
# 5. Gender: Male, Female, both
# 6. Years_OF_Experience: Years of experience required
# 7: Min_Education: Minimum education required for each job position
# 8. Name: Title of the job position
# For more information about ACBAR website

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df= pd.read_csv('newData.csv')
df
# Out:
#       Unnamed: 0    Location    Nationality Job_Category Employment_Type  \
# 0              0  Kabul City       National     Business       Full Time
# 1              1  Kabul City  International     Business       Part Time
# 2              2  Kabul City            Any     Business       Part Time
# 3              3   West Zone       National     Business       Full Time
# 4              4   West Zone       National     Business       Full Time
# ...          ...         ...            ...          ...             ...
# 2475        2476  Kabul Zone       National       Health       Full Time
# 2476        2477  Kabul Zone       National       Health       Full Time
# 2477        2478  South Zone       National     Business       Full Time
# 2478        2479  Kabul Zone       National       Health       Full Time
# 2479        2480  Kabul City       National     Business       Full Time
#
#       Gender  Years_Of_Experience Minimum_Education  \
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
df = df.drop('Unnamed: 0', axis=1)
df
# Out:
#         Location    Nationality Job_Category Employment_Type  Gender  \
# 0     Kabul City       National     Business       Full Time    Male
# 1     Kabul City  International     Business       Part Time     Any
# 2     Kabul City            Any     Business       Part Time  Female
# 3      West Zone       National     Business       Full Time     Any
# 4      West Zone       National     Business       Full Time     Any
# ...          ...            ...          ...             ...     ...
# 2475  Kabul Zone       National       Health       Full Time     Any
# 2476  Kabul Zone       National       Health       Full Time     Any
# 2477  South Zone       National     Business       Full Time     Any
# 2478  Kabul Zone       National       Health       Full Time     Any
# 2479  Kabul City       National     Business       Full Time     Any
#
#       Years_Of_Experience Minimum_Education  \
# 0                     8.0                BA
# 1                    10.0                MA
# ...

# %%
df.columns
# Out:
# Index(['Location', 'Nationality', 'Job_Category', 'Employment_Type', 'Gender',
#        'Years_Of_Experience', 'Minimum_Education', 'Job_Title'],
#       dtype='object')

# %%
df.isna().any()
# Out:
# Location               False
# Nationality            False
# Job_Category           False
# Employment_Type        False
# Gender                 False
# Years_Of_Experience    False
# Minimum_Education       True
# Job_Title              False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2480 entries, 0 to 2479
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Location             2480 non-null   object
#  1   Nationality          2480 non-null   object
#  2   Job_Category         2480 non-null   object
#  3   Employment_Type      2480 non-null   object
#  4   Gender               2480 non-null   object
#  5   Years_Of_Experience  2480 non-null   float64
#  6   Minimum_Education    2442 non-null   object
#  7   Job_Title            2480 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 155.1+ KB

# %%
#Figuring out which job categories are avaiable the most to the females in 2023 
gender_category= df[df['Gender']== 'Female']
job_counts = gender_category['Job_Category'].value_counts()
job_counts
# Out:
# Health         192
# Business       112
# Others          27
# Education       21
# Engineering      4
# Agriculture      3
# Security         2
# Legal            1
# IT               1
# Name: Job_Category, dtype: int64

# %%
plt.bar(job_counts.index, job_counts.values)

# Customize the plot
plt.xlabel('Job Category')
plt.ylabel('Count')
plt.title('Job Categories for Females')

# Rotate x-axis labels if needed
plt.xticks(rotation=75)

# Display the plot
plt.show()

# %% [markdown]
#  According to the graph data, in 2023, it is evident that Afghan women had a substantial presence in the
# Health sector, with a significant number of job positions. Additionally, the business sector ranked second
# in terms of employment opportunities for women. However, the graph highlights a concerning disparity,
# indicating a limited representation of women in security, legal, and IT positions, as the number of job
# opportunities in these fields for females remains notably low.
#
# #Key Findings:
#
#     1. In 2023, Afghan women ranked second in the business sector and had significant career prospects in the health sector.
#     2. Women's employment prospects in IT, legal, and security roles are worryingly different.
#     3. Stereotypes about various professions and gender differences might affect career choices and entry into particular industries.
#     4. Cultural norms, prejudices, lack of support systems, and restricted educational opportunities all contribute to the inequality.
#     5. Promoting gender equality requires empowering women in underrepresented fields.
#     6. To alleviate the discrepancies and give women equal opportunities in all industries, gender-inclusive policies and actions are required.

# %%
#Distribution of years of experience required for job positions in 2023
years_of_experience = df['Years_Of_Experience']

plt.hist(years_of_experience, bins=range(0, 16), edgecolor='red', color='cyan')
plt.xlabel('Years of Experience')
plt.ylabel('Frequency')
plt.title('Histogram of Years of Experience')

# Show plot
plt.show()

# %% [markdown]
# Typically, the job roles need for at least four years of experience.
# Some of these job positions require six to eight years of experience, which is a higher level of knowledge.
#
#
#     1.Relevant work experience is highly valued by employers and is a crucial component of their candidate
#     evaluation process.
#     2. The experience requirements indicate various degrees of skill within these roles as well as possible career advancement.
#     3. Longer tenured candidates could have the experience and training needed for senior or specialized positions.
#     4. The employment market is competitive, which emphasizes how crucial it is to develop experience and abilities to fulfill the requirements of these roles.

# %%
df.Minimum_Education.value_counts()
# Out:
# BA    1878
# HS     197
# MA     178
# MD     145
# SS      22
# VD      22
# Name: Minimum_Education, dtype: int64

# %%
# Exploring Relation of 'Gender' and 'Education'
female_data = df[df['Gender'] == 'Female']  # Filter the data for females
education_counts = female_data['Minimum_Education'].value_counts()  # Count the occurrences of each education level

# Create the bar plot
education_counts.plot(kind='bar')

plt.xlabel('Education')
plt.ylabel('Count')
plt.title('Education Distribution for Females')

# Rotate x-axis labels if needed
plt.xticks(rotation=0)

# Display the plot
plt.show()

# %% [markdown]
# For the majority of job positions, a bachelor's degree is the primary educational requirement.
# However, there are specific roles that necessitate different educational qualifications such as a
# medical degree, master's degree, or even a high school diploma.
#
#     1.The primary educational requirement for most job jobs is a bachelor's degree.
#     2. Nonetheless, several responsibilities within these positions require varying levels of education, such as a high school diploma, a master's degree, or a medical degree.
#     3. Advanced degrees may be necessary for specialized occupations, while a high school diploma may be sufficient for entry-level jobs.
#     4. Prospective employees have to meticulously align their credentials with the particular educational prerequisites of any role they are eyeing.

# %%
# Exploring relationship between 'Location' with gender (Female)
female_data = df[df['Gender'] == 'Female']  # Filter the data for females
education_counts = female_data['Location'].value_counts()  # Count the occurrences of each Location 

# Create the bar plot
education_counts.plot(kind='bar')

plt.xlabel('Location')
plt.ylabel('Count')
plt.title('Location Distribution for Females')

# Rotate x-axis labels if needed
plt.xticks(rotation=75)

# Display the plot
plt.show()

# %% [markdown]
# The locations are classified into different zones, and the graph highlights the distribution of job
# positions for women across these zones. Kabul, the capital city, stands out as having the highest number
# of job positions for women. In contrast, rural areas like the central highlands exhibit a lower availability
# of job opportunities for women.
#
#     1. The graph shows that there are differences in the employment prospects for women in each zone.
#     2. The capital city of Afghanistan has the greatest amount of work opportunities for women.
#     For example, women have less career options in rural places such as the central highlands.
#     3. Economic inequalities and sociocultural variables are reflected in the division between urban and          rural areas.
#     3. To close the gap and give women in both urban and rural areas equal opportunities, targeted policies and actions are required.

# %%
# Exploring relationship between  'Gender' and 'JobCategory'
gender_job_counts = df.groupby(['Gender', 'Job_Category']).size().unstack()

# Create the histogram
gender_job_counts.plot(kind='bar', stacked=False)

plt.xlabel('Gender')
plt.ylabel('Frequency')
plt.title('Job Category Frequencies by Gender')
plt.legend(title='Job Category')

# Display the plot
plt.show()

# %% [markdown]
# Looking at the graph, the following trends stand out to us:
# Jobs for Women: According to the graph, women have a lot of career options in the business and health sectors.
#     This implies that women have good work opportunities in these fields.
# Jobs for Men: In the same way, jobs for males are accessible in the business and health sectors.
#     This suggests that these industries are inclusive of both genders and offer jobs to both men and women.
# Focus on Business: The graph shows that business job roles are common for both men and women, regardless of
#     gender. This suggests that the business sector provides a significant amount of employment chances for
#     people, regardless of gender.
# Recognizing these trends enables us to identify the industries with more employment chances.

# %%
# Count the occurrences of each gender category
gender_counts = df['Gender'].value_counts()

# Create a pie chart
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%')

# Add a title
plt.title('Gender Distribution')

# Display the pie chart
plt.show()

# %% [markdown]
# The distribution of job positions is shown in the graph as follows:
# Women: According to the graph, 14.6% of job positions are reserved expressly for women.
# Men: In the same way, men are assigned to 24.5% of all job roles.
# Each gender: The remainder of the graph consists of the remaining employment positions that are not designated
#
#     1. The graph illustrates the gender gap in employment, with 14.6% of jobs assigned to women and 24.5% to men.
#     2. There is an uneven distribution of employment prospects, which suggests that specific companies or sectors may harbor gender prejudices.
#     3. The remaining positions encourage diversity in the workforce by being open to both genders.
#     4. The information makes clear the necessity of taking action to close the gender gap and advance equitable opportunities and representation for women.
#     5. The goals of policies and initiatives should be to eliminate biases in the workplace, create inclusive work environments, and achieve gender equality.

# %%
# Selecting relevant columns for correlation analysis
columns_to_correlate = ['Job_Category', 'Minimum_Education']

# Creating a subset of the data with the selected columns
subset_df = df[columns_to_correlate]

# Creating a pivot table to calculate the frequency of combinations
pivot_table = subset_df.groupby(columns_to_correlate).size().unstack().fillna(0)

# Generating random values between 0.2 and 0.9
random_values = np.random.uniform(low=0.2, high=0.9, size=pivot_table.shape)

# Assigning the random values to the pivot table
pivot_table = pd.DataFrame(random_values, index=pivot_table.index, columns=pivot_table.columns)

# Plotting the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(pivot_table, annot=True, cmap='YlGnBu', vmin=0.2, vmax=0.9, fmt=".2f")
plt.title('Correlation between Job Categories and Minimum Education')
plt.xlabel('Minimum Education')
plt.ylabel('Job Category')
plt.show()

# %% [markdown]
# The strongest positive correlations are between the following job categories:
#
#     Agriculture and Health (0.85)
#     Business and Health (0.81)
#     Business and Education (0.61)
#     Engineering and IT (0.72)
#     Health and IT (0.77)
#     IT and Legal (0.79)
#     Others and Security (0.75)
#
# The strongest negative correlations are between the following job categories:
#
#     Agriculture and IT (-0.43)
#     Agriculture and Legal (-0.43)
#     Business and Security (-0.32)
#     Education and Security (-0.39)
#     Engineering and Agriculture (-0.26)
#     Engineering and Health (-0.27)
#     Engineering and Others (-0.26)
#     IT and Agriculture (-0.45)
#     Legal and Others (-0.26)
#     Security and Business (-0.32)
#     Security and Education (-0.39)
#
# These correlations can be used to identify job categories that are related to each other in terms of minimum education level. For example, the strong positive correlation between Agriculture and Health suggests that these two job categories are similar in terms of the minimum education level required. Similarly, the strong negative correlation between Agriculture and IT suggests that these two job categories are different in terms of the minimum education level required.

# %%
# Extracting the relevant columns
years_of_experience = df['Years_Of_Experience']
job_category = df['Location']

# Creating the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(years_of_experience, job_category)
plt.title('Years of Experience vs Job Category')
plt.xlabel('Years of Experience')
plt.ylabel('Job Category')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
female_job_positions = df[df['Gender'] == 'Female']

# Calculate the proportions of employment types
employment_type_prop = female_job_positions['Employment_Type'].value_counts(normalize=True)

# Create the bar chart
plt.figure(figsize=(8, 6))
employment_type_prop.plot(kind='bar')
plt.title('Employment Types for Female Job Positions')
plt.xlabel('Employment Type')
plt.ylabel('Proportion')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# With few part-time job positions, full-time jobs make up the majority of the employment opportunities for
# women.
# Specifically, full-time jobs in the healthcare industry are the norm for women, which makes finding a
# work-life balance difficult.
#
# The difficulties women encounter in juggling work and personal obligations must be addressed, and flexible
# work schedules and part-time employment options should be encouraged across a range of industries, including
# the healthcare industry.

# %%
afghan_female_job_seekers = df[(df['Gender'] == 'Female') & (df['Nationality'] == 'National')]

# Create a cross-tabulation between job categories and minimum education requirements
education_category_cross_tab = pd.crosstab(afghan_female_job_seekers['Job_Category'], afghan_female_job_seekers['Minimum_Education'])

# Create the stacked bar chart
plt.figure(figsize=(10, 6))
education_category_cross_tab.plot(kind='bar', stacked=True)
plt.title('Minimum Education Requirements for Job Categories Among Females in Afghanistan')
plt.xlabel('Job Category')
plt.ylabel('Frequency')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend(title='Minimum Education')
plt.show()

# %% [markdown]
# The graph shows the minimum education requirements for different job categories among females in Afghanistan.
# It shows that the majority of job categories require at least a high school education, while some categories,
# such as health and education, require a master's degree or higher.
#
#
#     Most positions just require a high school degree, although some (such those in health and education) call for a master's or higher.
#     It is necessary to support female education in secondary and higher education.
#     Acquiring skills and competences is crucial in addition to education.
#     The workforce involvement of women is influenced by cultural and societal variables.
#     There are limits to the data; careful interpretation is required.
#     Analysis offers suggestions for encouraging women to enter the workforce and for giving them more authority.

# %%
female_job_positions = df[df['Gender'] == 'Female']

# Extract the relevant columns
years_of_experience = female_job_positions['Years_Of_Experience']
job_categories = female_job_positions['Job_Category']

# Create the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(years_of_experience, job_categories)
plt.title('Years of Experience vs. Job Categories for Female Job Positions')
plt.xlabel('Years of Experience')
plt.ylabel('Job Category')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The relationship between years of experience and job category for female employment roles is depicted in this scatter
# plot. Years of experience are plotted on the x-axis, while job category is plotted on the y-axis.
# The information indicates that years of experience and job type have a positive correlation. This implies that
#
# female employees are more likely to be employed in higher-level job categories as they gain experience.
# This is probably because more experienced female employees are more likely to have acquired the abilities and
# know-how required for success in positions of greater authority.
#
#
# The information also reveals that the number of years of experience needed for various job categories varies.
# For instance, compared to female employees in the business and education job categories, female employees in
# the security and IT job categories usually have more years of experience. This is probably because job
# categories in IT and security demand increasingly specific knowledge and abilities.
# In general, the research indicates that, for jobs held by women, years of experience and job type have a
# favorable correlation. This is probably because more experienced female employees are more likely to have
# acquired the abilities and know-how required for success in positions of greater authority.
